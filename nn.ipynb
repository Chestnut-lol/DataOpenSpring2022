# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

# %%
#loads all the provided datasets
orders = pd.read_csv("BigSupplyCo_Orders.csv",index_col=0)
product_cat = pd.read_csv("BigSupplyCo_Categories.csv",index_col=0)
products = pd.read_csv("BigSupplyCo_Products.csv")
departments = pd.read_csv("BigSupplyCo_Departments_Cleaned.csv")

# %%
#merges product categories on products
products = pd.merge(left=products,right=product_cat,left_on="Product Category Id",right_on="Category Id",how="left")
products.set_index("Product Card Id",inplace=True)

# %%
#merges products on orders
orders = pd.merge(left=orders,right=products,left_on="Order Item Cardprod Id",right_on="Product Card Id",how="left")

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180519 entries, 0 to 180518
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Order Id                       180519 non-null  int64
#  1   Order Item Cardprod Id         180519 non-null  int64
#  2   Order Customer Id              180519 non-null  int64
#  3   Order Department Id            180519 non-null  int64
#  4   Market                         180519 non-null  object
#  5   Order City                     180519 non-null  object
#  6   Order Country                  180519 non-null  object
#  7   Order Region                   180519 non-null  object
#  8   Order State                    180519 non-null  object
#  9   Order Status                   180519 non-null  object
#  10  Order Zipcode                  24840 non-null   float64
#  11  order date (DateOrders)        180519 non-null  object
#  12  Order Item Discount            180519 non-null  float64
#  13  Order Item Discount Rate       180519 non-null  float64
#  14  Order Item Id                  180519 non-null  int64
#  15  Order Item Quantity            180519 non-null  int64
#  16  Sales                          180519 non-null  float64
#  17  Order Item Total               180519 non-null  float64
#  18  Order Profit                   180519 non-null  float64
#  19  Type                           180519 non-null  object
#  20  Days for shipping (real)       180519 non-null  int64
#  21  Days for shipment (scheduled)  180519 non-null  int64
#  22  Delivery Status                180519 non-null  object
#  23  Late Delivery Risk             180519 non-null  int64
#  24  Product Category Id            180519 non-null  int64
#  25  Product Description            0 non-null       float64
#  26  Product Image                  180519 non-null  object
#  27  Product Name                   180519 non-null  object
#  28  Product Price                  180519 non-null  float64
#  29  Product Status                 180519 non-null  int64
#  30  Category Name                  180519 non-null  object
# dtypes: float64(8), int64(11), object(12)
# memory usage: 44.1+ MB

# %%
orders[["Order City","Order Country","Order State","Order Status","Delivery Status","Late Delivery Risk"]][:20]
# Out:
#     Order City  Order Country            Order State     Order Status  \
# 0       Bekasi      Indonesia        Java Occidental         COMPLETE
# 1      Bikaner          India               Rajastán          PENDING
# 2      Bikaner          India               Rajastán           CLOSED
# 3   Townsville      Australia             Queensland         COMPLETE
# 4   Townsville      Australia             Queensland  PENDING_PAYMENT
# 5    Toowoomba      Australia             Queensland         CANCELED
# 6    Guangzhou          China              Guangdong         COMPLETE
# 7    Guangzhou          China              Guangdong       PROCESSING
# 8    Guangzhou          China              Guangdong           CLOSED
# 9    Guangzhou          China              Guangdong           CLOSED
# 10       Tokio          Japón                  Tokio  SUSPECTED_FRAUD
# 11      Manado      Indonesia  Célebes Septentrional          PENDING
# 12      Manado      Indonesia  Célebes Septentrional          PENDING
# 13      Sangli          India            Maharashtra         COMPLETE
# 14      Sangli          India            Maharashtra       PROCESSING
# 15      Sangli          India            Maharashtra         COMPLETE
# 16        Seúl  Corea del Sur                   Seúl  PENDING_PAYMENT
# 17    Jabalpur          India         Madhya Pradesh           CLOSED
# 18    Jabalpur          India         Madhya Pradesh         COMPLETE
# 19    Jabalpur          India         Madhya Pradesh  PENDING_PAYMENT
#
#       Delivery Status  Late Delivery Risk
# 0    Advance shipping                   0
# 1       Late delivery                   1
# 2    Shipping on time                   0
# 3    Advance shipping                   0
# 4    Advance shipping                   0
# 5   Shipping canceled                   0
# 6       Late delivery                   1
# 7       Late delivery                   1
# 8       Late delivery                   1
# 9       Late delivery                   1
# 10  Shipping canceled                   0
# 11      Late delivery                   1
# 12      Late delivery                   1
# 13      Late delivery                   1
# 14      Late delivery                   1
# 15      Late delivery                   1
# 16      Late delivery                   1
# 17      Late delivery                   1
# 18      Late delivery                   1
# 19   Shipping on time                   0

# %%
orders["Order City"].unique() == orders["Order State"]
# Out:
# C:\Users\LH\AppData\Local\Temp/ipykernel_7432/853341576.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   orders["Order City"].unique() == orders["Order State"]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7432/853341576.py in <module>
# ----> 1 orders["Order City"].unique() == orders["Order State"]
#
# c:\users\lh\tf_env\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# c:\users\lh\tf_env\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# c:\users\lh\tf_env\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# c:\users\lh\tf_env\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     259         #  The ambiguous case is object-dtype.  See GH#27803
#     260         if len(lvalues) != len(rvalues):
# --> 261             raise ValueError(
#     262                 "Lengths must match to compare", lvalues.shape, rvalues.shape
#     263             )
#
# ValueError: ('Lengths must match to compare', (180519,), (3597,))

# %%
df = pd.read_csv("https://raw.githubusercontent.com/weijuinlee/datathon/main/BigSupplyCo_Data_Files%20/geolocateddataset.csv?token=GHSAT0AAAAAABMK6536E2YPUFJAZVX3NG74YRTMEMA",index_col=0)

# %%
cols = [
    "Late Delivery Risk"
    "Market",
    "Category Name"
]
# Out:
#         Order Id  Order Department Id        Market  Order City Order Country  \
# 0          77202                    2  Pacific Asia      Bekasi     Indonesia
# 1          75939                    2  Pacific Asia     Bikaner         India
# 2          75938                    2  Pacific Asia     Bikaner         India
# 3          75937                    2  Pacific Asia  Townsville     Australia
# 4          75936                    2  Pacific Asia  Townsville     Australia
# ...          ...                  ...           ...         ...           ...
# 180514     26043                    7  Pacific Asia    Shanghái         China
# 180515     26037                    7  Pacific Asia    Hirakata         Japan
# 180516     26024                    7  Pacific Asia    Adelaide     Australia
# 180517     26022                    7  Pacific Asia    Adelaide     Australia
# 180518     26018                    7  Pacific Asia   Nagercoil         India
#
#           Order Region        Order State     Order Status  Order Zipcode  \
# 0       Southeast Asia    Java Occidental         COMPLETE            NaN
# 1           South Asia           Rajastán          PENDING            NaN
# 2           South Asia           Rajastán           CLOSED            NaN
# 3              Oceania         Queensland         COMPLETE            NaN
# 4              Oceania         Queensland  PENDING_PAYMENT            NaN
# ...                ...                ...              ...            ...
# 180514    Eastern Asia           Shanghái           CLOSED            NaN
# 180515    Eastern Asia              Osaka         COMPLETE            NaN
# 180516         Oceania  Australia del Sur          PENDING            NaN
# 180517         Oceania  Australia del Sur  PENDING_PAYMENT            NaN
# 180518      South Asia         Tamil Nadu  PENDING_PAYMENT            NaN
#
#        order date (DateOrders)  ...  Product Status  Customer Id  \
# 0              1/31/2018 22:56  ...               0        20755
# 1              1/13/2018 12:27  ...               0        19492
# 2              1/13/2018 12:06  ...               0        19491
# 3              1/13/2018 11:45  ...               0        19490
# 4              1/13/2018 11:24  ...               0        19489
# ...                        ...  ...             ...          ...
# 180514          1/16/2016 3:40  ...               0         1005
# 180515          1/16/2016 1:34  ...               0         9141
# 180516         1/15/2016 21:00  ...               0          291
# 180517         1/15/2016 20:18  ...               0         2813
# 180518         1/15/2016 18:54  ...               0         7547
#
#         Customer City  Customer Country  Customer Segment  Customer State  \
# 0              Caguas       Puerto Rico          Consumer              PR
# 1              Caguas       Puerto Rico          Consumer              PR
# 2            San Jose           EE. UU.          Consumer              CA
# 3         Los Angeles           EE. UU.       Home Office              CA
# 4              Caguas       Puerto Rico         Corporate              PR
# ...               ...               ...               ...             ...
# 180514       Brooklyn           EE. UU.       Home Office              NY
# 180515    Bakersfield           EE. UU.         Corporate              CA
# 180516        Bristol           EE. UU.         Corporate              CT
# 180517         Caguas       Puerto Rico          Consumer              PR
# 180518         Caguas       Puerto Rico          Consumer              PR
#
#         Customer Zipcode   Category Name        lat        long
# 0                  725.0  Sporting Goods  -6.234986  106.994544
# 1                  725.0  Sporting Goods  28.015929   73.317137
# 2                95125.0  Sporting Goods  28.015929   73.317137
# 3                90027.0  Sporting Goods -19.256939  146.823954
# 4                  725.0  Sporting Goods -19.256939  146.823954
# ...                  ...             ...        ...         ...
# 180514           11207.0         Fishing  31.232276  121.469207
# 180515           93304.0         Fishing  34.818215  135.659225
# 180516            6010.0         Fishing -34.928181  138.599931
# 180517             725.0         Fishing -34.928181  138.599931
# 180518             725.0         Fishing   8.188047   77.429049
#
# [180519 rows x 36 columns]

# %%
corrMatrix = df.corr()
corrMatrix
# Out:
#                                Order Id  Order Department Id  Order Zipcode  \
# Order Id                       1.000000             0.106757       0.013971
# Order Department Id            0.106757             1.000000      -0.005982
# Order Zipcode                  0.013971            -0.005982       1.000000
# Order Item Discount            0.049385             0.144617       0.003921
# Order Item Discount Rate       0.000484             0.000255       0.002691
# Order Item Id                  0.999623             0.101676       0.013867
# Order Item Quantity           -0.087073            -0.265437       0.001662
# Sales                          0.079835             0.234718       0.000564
# Order Item Total               0.079000             0.232367      -0.000138
# Order Profit                   0.013716             0.031442      -0.004978
# Days for shipping (real)      -0.001711            -0.001631      -0.000811
# Days for shipment (scheduled) -0.001878            -0.000262       0.005249
# Late Delivery Risk            -0.001293             0.001077      -0.014131
# Product Card Id                0.163416             0.906117      -0.005658
# Product Category Id            0.198496             0.888835      -0.005943
# Product Price                  0.115324             0.446743      -0.000121
# Product Status                      NaN                  NaN            NaN
# Customer Id                    0.204821             0.136897      -0.005659
# Customer Zipcode              -0.001210             0.002878       0.011843
# lat                            0.092637            -0.007957      -0.146371
# long                           0.056627             0.062211      -0.833968
#
#                                Order Item Discount  Order Item Discount Rate  \
# Order Id                                  0.049385                  0.000484
# Order Department Id                       0.144617                  0.000255
# Order Zipcode                             0.003921                  0.002691
# Order Item Discount                       1.000000                  0.659955
# Order Item Discount Rate                  0.659955                  1.000000
# Order Item Id                             0.048866                  0.000471
# Order Item Quantity                       0.065379                 -0.000028
# Sales                                     0.617438                  0.000346
# Order Item Total                          0.498734                 -0.119469
# Order Profit                              0.064756                 -0.018644
# Days for shipping (real)                  0.002231                  0.001467
# Days for shipment (scheduled)             0.002897                  0.000065
# Late Delivery Risk                       -0.000750                  0.000404
# Product Card Id                           0.147294                  0.000731
# Product Category Id                       0.140180                  0.000572
# Product Price                             0.488101                  0.000345
# Product Status                                 NaN                       NaN
# Customer Id                               0.038490                  0.001712
# Customer Zipcode                         -0.001861                 -0.000135
# lat                                       0.018902                 -0.003138
# long                                      0.008968                  0.001052
#
#                                Order Item Id  Order Item Quantity     Sales  \
# Order Id                            0.999623            -0.087073  0.079835
# Order Department Id                 0.101676            -0.265437  0.234718
# Order Zipcode                       0.013867             0.001662  0.000564
# Order Item Discount                 0.048866             0.065379  0.617438
# Order Item Discount Rate            0.000471            -0.000028  0.000346
# Order Item Id                       1.000000            -0.083643  0.079002
# Order Item Quantity                -0.083643             1.000000  0.106442
# Sales                               0.079002             0.106442  1.000000
# Order Item Total                    0.078176             0.105413  0.989744
# Order Profit                        0.013556             0.015696  0.131816
# Days for shipping (real)           -0.001769            -0.000811  0.001962
# Days for shipment (scheduled)      -0.001848            -0.002925  0.006327
# Late Delivery Risk                 -0.001376            -0.000139 -0.003564
# Product Card Id                     0.154077            -0.312555  0.238789
# Product Category Id                 0.186796            -0.302408  0.227483
# Product Price                       0.112448            -0.476232  0.789948
# Product Status                           NaN                  NaN       NaN
# Customer Id                         0.191814            -0.091328  0.060961
# Customer Zipcode                   -0.001208            -0.006174 -0.001490
# lat                                 0.096182             0.000816  0.034297
# long                                0.049620            -0.044105  0.013132
#
#                                Order Item Total  Order Profit  ...  \
# Order Id                               0.079000      0.013716  ...
# Order Department Id                    0.232367      0.031442  ...
# Order Zipcode                         -0.000138     -0.004978  ...
# Order Item Discount                    0.498734      0.064756  ...
# Order Item Discount Rate              -0.119469     -0.018644  ...
# Order Item Id                          0.078176      0.013556  ...
# Order Item Quantity                    0.105413      0.015696  ...
# Sales                                  0.989744      0.131816  ...
# Order Item Total                       1.000000      0.133484  ...
# Order Profit                           0.133484      1.000000  ...
# Days for shipping (real)               0.001757     -0.005101  ...
# Days for shipment (scheduled)          0.006445     -0.000185  ...
# Late Delivery Risk                    -0.003791     -0.003727  ...
# Product Card Id                        0.236367      0.033161  ...
# Product Category Id                    0.225201      0.031889  ...
# Product Price                          0.781781      0.103459  ...
# Product Status                              NaN           NaN  ...
# Customer Id                            0.060181      0.009354  ...
# Customer Zipcode                      -0.001304      0.002235  ...
# lat                                    0.034358      0.005882  ...
# long                                   0.012841     -0.002442  ...
#
#                                Days for shipment (scheduled)  \
# Order Id                                           -0.001878
# Order Department Id                                -0.000262
# Order Zipcode                                       0.005249
# Order Item Discount                                 0.002897
# Order Item Discount Rate                            0.000065
# Order Item Id                                      -0.001848
# Order Item Quantity                                -0.002925
# Sales                                               0.006327
# Order Item Total                                    0.006445
# Order Profit                                       -0.000185
# Days for shipping (real)                            0.515880
# Days for shipment (scheduled)                       1.000000
# Late Delivery Risk                                 -0.369352
# Product Card Id                                    -0.000431
# Product Category Id                                -0.000367
# Product Price                                       0.006912
# Product Status                                           NaN
# Customer Id                                         0.000899
# Customer Zipcode                                   -0.003019
# lat                                                -0.009263
# long                                               -0.000584
#
#                                Late Delivery Risk  Product Card Id  \
# Order Id                                -0.001293         0.163416
# Order Department Id                      0.001077         0.906117
# Order Zipcode                           -0.014131        -0.005658
# Order Item Discount                     -0.000750         0.147294
# Order Item Discount Rate                 0.000404         0.000731
# Order Item Id                           -0.001376         0.154077
# Order Item Quantity                     -0.000139        -0.312555
# Sales                                   -0.003564         0.238789
# Order Item Total                        -0.003791         0.236367
# Order Profit                            -0.003727         0.033161
# Days for shipping (real)                 0.401415        -0.000859
# Days for shipment (scheduled)           -0.369352        -0.000431
# Late Delivery Risk                       1.000000         0.001490
# Product Card Id                          0.001490         1.000000
# Product Category Id                      0.001752         0.991092
# Product Price                           -0.002175         0.480288
# Product Status                                NaN              NaN
# Customer Id                              0.001484         0.228039
# Customer Zipcode                         0.003148         0.003173
# lat                                      0.003301        -0.022439
# long                                     0.002761         0.108069
#
#                                Product Category Id  Product Price  \
# Order Id                                  0.198496       0.115324
# Order Department Id                       0.888835       0.446743
# Order Zipcode                            -0.005943      -0.000121
# Order Item Discount                       0.140180       0.488101
# Order Item Discount Rate                  0.000572       0.000345
# Order Item Id                             0.186796       0.112448
# Order Item Quantity                      -0.302408      -0.476232
# Sales                                     0.227483       0.789948
# Order Item Total                          0.225201       0.781781
# Order Profit                              0.031889       0.103459
# Days for shipping (real)                 -0.000348       0.002185
# Days for shipment (scheduled)            -0.000367       0.006912
# Late Delivery Risk                        0.001752      -0.002175
# Product Card Id                           0.991092       0.480288
# Product Category Id                       1.000000       0.461059
# Product Price                             0.461059       1.000000
# Product Status                                 NaN            NaN
# Customer Id                               0.274633       0.111118
# Customer Zipcode                          0.002898       0.002191
# lat                                      -0.031831       0.029407
# long                                      0.133579       0.038520
#
#                                Product Status  Customer Id  Customer Zipcode  \
# Order Id                                  NaN     0.204821         -0.001210
# Order Department Id                       NaN     0.136897          0.002878
# Order Zipcode                             NaN    -0.005659          0.011843
# Order Item Discount                       NaN     0.038490         -0.001861
# Order Item Discount Rate                  NaN     0.001712         -0.000135
# Order Item Id                             NaN     0.191814         -0.001208
# Order Item Quantity                       NaN    -0.091328         -0.006174
# Sales                                     NaN     0.060961         -0.001490
# Order Item Total                          NaN     0.060181         -0.001304
# Order Profit                              NaN     0.009354          0.002235
# Days for shipping (real)                  NaN     0.003432          0.000112
# Days for shipment (scheduled)             NaN     0.000899         -0.003019
# Late Delivery Risk                        NaN     0.001484          0.003148
# Product Card Id                           NaN     0.228039          0.003173
# Product Category Id                       NaN     0.274633          0.002898
# Product Price                             NaN     0.111118          0.002191
# Product Status                            NaN          NaN               NaN
# Customer Id                               NaN     1.000000          0.002022
# Customer Zipcode                          NaN     0.002022          1.000000
# lat                                       NaN    -0.039496         -0.004001
# long                                      NaN     0.143470          0.001927
#
#                                     lat      long
# Order Id                       0.092637  0.056627
# Order Department Id           -0.007957  0.062211
# Order Zipcode                 -0.146371 -0.833968
# Order Item Discount            0.018902  0.008968
# Order Item Discount Rate      -0.003138  0.001052
# Order Item Id                  0.096182  0.049620
# Order Item Quantity            0.000816 -0.044105
# Sales                          0.034297  0.013132
# Order Item Total               0.034358  0.012841
# Order Profit                   0.005882 -0.002442
# Days for shipping (real)      -0.006436  0.000188
# Days for shipment (scheduled) -0.009263 -0.000584
# Late Delivery Risk             0.003301  0.002761
# Product Card Id               -0.022439  0.108069
# Product Category Id           -0.031831  0.133579
# Product Price                  0.029407  0.038520
# Product Status                      NaN       NaN
# Customer Id                   -0.039496  0.143470
# Customer Zipcode              -0.004001  0.001927
# lat                            1.000000 -0.224196
# long                          -0.224196  1.000000
#
# [21 rows x 21 columns]

# %%
mat = pd.DataFrame(corrMatrix["Late Delivery Risk"])

# %%
mat
# Out:
#                                Late Delivery Risk
# Order Id                                -0.001293
# Order Department Id                      0.001077
# Order Zipcode                           -0.014131
# Order Item Discount                     -0.000750
# Order Item Discount Rate                 0.000404
# Order Item Id                           -0.001376
# Order Item Quantity                     -0.000139
# Sales                                   -0.003564
# Order Item Total                        -0.003791
# Order Profit                            -0.003727
# Days for shipping (real)                 0.401415
# Days for shipment (scheduled)           -0.369352
# Late Delivery Risk                       1.000000
# Product Card Id                          0.001490
# Product Category Id                      0.001752
# Product Price                           -0.002175
# Product Status                                NaN
# Customer Id                              0.001484
# Customer Zipcode                         0.003148
# lat                                      0.003301
# long                                     0.002761

# %%
# Out:
#                                Order Id  Order Department Id  Order Zipcode  \
# Order Id                       1.000000             0.106757       0.013971
# Order Department Id            0.106757             1.000000      -0.005982
# Order Zipcode                  0.013971            -0.005982       1.000000
# Order Item Discount            0.049385             0.144617       0.003921
# Order Item Discount Rate       0.000484             0.000255       0.002691
# Order Item Id                  0.999623             0.101676       0.013867
# Order Item Quantity           -0.087073            -0.265437       0.001662
# Sales                          0.079835             0.234718       0.000564
# Order Item Total               0.079000             0.232367      -0.000138
# Order Profit                   0.013716             0.031442      -0.004978
# Days for shipping (real)      -0.001711            -0.001631      -0.000811
# Days for shipment (scheduled) -0.001878            -0.000262       0.005249
# Late Delivery Risk            -0.001293             0.001077      -0.014131
# Product Card Id                0.163416             0.906117      -0.005658
# Product Category Id            0.198496             0.888835      -0.005943
# Product Price                  0.115324             0.446743      -0.000121
# Product Status                      NaN                  NaN            NaN
# Customer Id                    0.204821             0.136897      -0.005659
# Customer Zipcode              -0.001210             0.002878       0.011843
# lat                            0.092637            -0.007957      -0.146371
# long                           0.056627             0.062211      -0.833968
#
#                                Order Item Discount  Order Item Discount Rate  \
# Order Id                                  0.049385                  0.000484
# Order Department Id                       0.144617                  0.000255
# Order Zipcode                             0.003921                  0.002691
# Order Item Discount                       1.000000                  0.659955
# Order Item Discount Rate                  0.659955                  1.000000
# Order Item Id                             0.048866                  0.000471
# Order Item Quantity                       0.065379                 -0.000028
# Sales                                     0.617438                  0.000346
# Order Item Total                          0.498734                 -0.119469
# Order Profit                              0.064756                 -0.018644
# Days for shipping (real)                  0.002231                  0.001467
# Days for shipment (scheduled)             0.002897                  0.000065
# Late Delivery Risk                       -0.000750                  0.000404
# Product Card Id                           0.147294                  0.000731
# Product Category Id                       0.140180                  0.000572
# Product Price                             0.488101                  0.000345
# Product Status                                 NaN                       NaN
# Customer Id                               0.038490                  0.001712
# Customer Zipcode                         -0.001861                 -0.000135
# lat                                       0.018902                 -0.003138
# long                                      0.008968                  0.001052
#
#                                Order Item Id  Order Item Quantity     Sales  \
# Order Id                            0.999623            -0.087073  0.079835
# Order Department Id                 0.101676            -0.265437  0.234718
# Order Zipcode                       0.013867             0.001662  0.000564
# Order Item Discount                 0.048866             0.065379  0.617438
# Order Item Discount Rate            0.000471            -0.000028  0.000346
# Order Item Id                       1.000000            -0.083643  0.079002
# Order Item Quantity                -0.083643             1.000000  0.106442
# Sales                               0.079002             0.106442  1.000000
# Order Item Total                    0.078176             0.105413  0.989744
# Order Profit                        0.013556             0.015696  0.131816
# Days for shipping (real)           -0.001769            -0.000811  0.001962
# Days for shipment (scheduled)      -0.001848            -0.002925  0.006327
# Late Delivery Risk                 -0.001376            -0.000139 -0.003564
# Product Card Id                     0.154077            -0.312555  0.238789
# Product Category Id                 0.186796            -0.302408  0.227483
# Product Price                       0.112448            -0.476232  0.789948
# Product Status                           NaN                  NaN       NaN
# Customer Id                         0.191814            -0.091328  0.060961
# Customer Zipcode                   -0.001208            -0.006174 -0.001490
# lat                                 0.096182             0.000816  0.034297
# long                                0.049620            -0.044105  0.013132
#
#                                Order Item Total  Order Profit  ...  \
# Order Id                               0.079000      0.013716  ...
# Order Department Id                    0.232367      0.031442  ...
# Order Zipcode                         -0.000138     -0.004978  ...
# Order Item Discount                    0.498734      0.064756  ...
# Order Item Discount Rate              -0.119469     -0.018644  ...
# Order Item Id                          0.078176      0.013556  ...
# Order Item Quantity                    0.105413      0.015696  ...
# Sales                                  0.989744      0.131816  ...
# Order Item Total                       1.000000      0.133484  ...
# Order Profit                           0.133484      1.000000  ...
# Days for shipping (real)               0.001757     -0.005101  ...
# Days for shipment (scheduled)          0.006445     -0.000185  ...
# Late Delivery Risk                    -0.003791     -0.003727  ...
# Product Card Id                        0.236367      0.033161  ...
# Product Category Id                    0.225201      0.031889  ...
# Product Price                          0.781781      0.103459  ...
# Product Status                              NaN           NaN  ...
# Customer Id                            0.060181      0.009354  ...
# Customer Zipcode                      -0.001304      0.002235  ...
# lat                                    0.034358      0.005882  ...
# long                                   0.012841     -0.002442  ...
#
#                                Days for shipment (scheduled)  \
# Order Id                                           -0.001878
# Order Department Id                                -0.000262
# Order Zipcode                                       0.005249
# Order Item Discount                                 0.002897
# Order Item Discount Rate                            0.000065
# Order Item Id                                      -0.001848
# Order Item Quantity                                -0.002925
# Sales                                               0.006327
# Order Item Total                                    0.006445
# Order Profit                                       -0.000185
# Days for shipping (real)                            0.515880
# Days for shipment (scheduled)                       1.000000
# Late Delivery Risk                                 -0.369352
# Product Card Id                                    -0.000431
# Product Category Id                                -0.000367
# Product Price                                       0.006912
# Product Status                                           NaN
# Customer Id                                         0.000899
# Customer Zipcode                                   -0.003019
# lat                                                -0.009263
# long                                               -0.000584
#
#                                Late Delivery Risk  Product Card Id  \
# Order Id                                -0.001293         0.163416
# Order Department Id                      0.001077         0.906117
# Order Zipcode                           -0.014131        -0.005658
# Order Item Discount                     -0.000750         0.147294
# Order Item Discount Rate                 0.000404         0.000731
# Order Item Id                           -0.001376         0.154077
# Order Item Quantity                     -0.000139        -0.312555
# Sales                                   -0.003564         0.238789
# Order Item Total                        -0.003791         0.236367
# Order Profit                            -0.003727         0.033161
# Days for shipping (real)                 0.401415        -0.000859
# Days for shipment (scheduled)           -0.369352        -0.000431
# Late Delivery Risk                       1.000000         0.001490
# Product Card Id                          0.001490         1.000000
# Product Category Id                      0.001752         0.991092
# Product Price                           -0.002175         0.480288
# Product Status                                NaN              NaN
# Customer Id                              0.001484         0.228039
# Customer Zipcode                         0.003148         0.003173
# lat                                      0.003301        -0.022439
# long                                     0.002761         0.108069
#
#                                Product Category Id  Product Price  \
# Order Id                                  0.198496       0.115324
# Order Department Id                       0.888835       0.446743
# Order Zipcode                            -0.005943      -0.000121
# Order Item Discount                       0.140180       0.488101
# Order Item Discount Rate                  0.000572       0.000345
# Order Item Id                             0.186796       0.112448
# Order Item Quantity                      -0.302408      -0.476232
# Sales                                     0.227483       0.789948
# Order Item Total                          0.225201       0.781781
# Order Profit                              0.031889       0.103459
# Days for shipping (real)                 -0.000348       0.002185
# Days for shipment (scheduled)            -0.000367       0.006912
# Late Delivery Risk                        0.001752      -0.002175
# Product Card Id                           0.991092       0.480288
# Product Category Id                       1.000000       0.461059
# Product Price                             0.461059       1.000000
# Product Status                                 NaN            NaN
# Customer Id                               0.274633       0.111118
# Customer Zipcode                          0.002898       0.002191
# lat                                      -0.031831       0.029407
# long                                      0.133579       0.038520
#
#                                Product Status  Customer Id  Customer Zipcode  \
# Order Id                                  NaN     0.204821         -0.001210
# Order Department Id                       NaN     0.136897          0.002878
# Order Zipcode                             NaN    -0.005659          0.011843
# Order Item Discount                       NaN     0.038490         -0.001861
# Order Item Discount Rate                  NaN     0.001712         -0.000135
# Order Item Id                             NaN     0.191814         -0.001208
# Order Item Quantity                       NaN    -0.091328         -0.006174
# Sales                                     NaN     0.060961         -0.001490
# Order Item Total                          NaN     0.060181         -0.001304
# Order Profit                              NaN     0.009354          0.002235
# Days for shipping (real)                  NaN     0.003432          0.000112
# Days for shipment (scheduled)             NaN     0.000899         -0.003019
# Late Delivery Risk                        NaN     0.001484          0.003148
# Product Card Id                           NaN     0.228039          0.003173
# Product Category Id                       NaN     0.274633          0.002898
# Product Price                             NaN     0.111118          0.002191
# Product Status                            NaN          NaN               NaN
# Customer Id                               NaN     1.000000          0.002022
# Customer Zipcode                          NaN     0.002022          1.000000
# lat                                       NaN    -0.039496         -0.004001
# long                                      NaN     0.143470          0.001927
#
#                                     lat      long
# Order Id                       0.092637  0.056627
# Order Department Id           -0.007957  0.062211
# Order Zipcode                 -0.146371 -0.833968
# Order Item Discount            0.018902  0.008968
# Order Item Discount Rate      -0.003138  0.001052
# Order Item Id                  0.096182  0.049620
# Order Item Quantity            0.000816 -0.044105
# Sales                          0.034297  0.013132
# Order Item Total               0.034358  0.012841
# Order Profit                   0.005882 -0.002442
# Days for shipping (real)      -0.006436  0.000188
# Days for shipment (scheduled) -0.009263 -0.000584
# Late Delivery Risk             0.003301  0.002761
# Product Card Id               -0.022439  0.108069
# Product Category Id           -0.031831  0.133579
# Product Price                  0.029407  0.038520
# Product Status                      NaN       NaN
# Customer Id                   -0.039496  0.143470
# Customer Zipcode              -0.004001  0.001927
# lat                            1.000000 -0.224196
# long                          -0.224196  1.000000
#
# [21 rows x 21 columns]

# %%
import seaborn as sns
